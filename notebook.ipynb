# %% [markdown]
# # AniCalendar Test Notebook
#
# This is used for development phase for easier coding

# %%
from src.api import get_user_medialist
from src.data import AiringListData


data = get_user_medialist("ChuckySRB")
airing_data = AiringListData(data, "Winter", 2026)

# %%
for media in airing_data.airing_anilist:
    print(media)
# Out:
# {'id': 182587, 'title': {'english': '【OSHI NO KO】Season 3', 'romaji': '[Oshi no Ko] 3rd Season'}, 'season': 'WINTER', 'seasonYear': 2026, 'episodes': None, 'airingSchedule': {'nodes': []}, 'startDate': {'year': 2026, 'month': 1, 'day': 14}}
# ...
